# %%
import functions as func

# %%
# Assign key to your songkick api key
# Populate the list with the names of the cities you would like to get data for
# Assign to cid and secret your spotify client ID and client secret respectively

key = ''
cities = ['']

cid = ''
secret = ''

# %%
# This will add csvs for each city in cities to the working directory

func.create_songkick_csvs(cities, key, cid, secret)
# Out:
# ['Confessions To My Unborn Daughter', 'Vartha', 'Where The River Goes', 'a blooming bloodfruit in a hoodie', 'Ceaseless Inexhaustible Child (Cyntoia Brown)']
# [youtube] c4yRqmkOveg: Downloading webpage
# [youtube] c4yRqmkOveg: Downloading video info webpage
# [download] Destination: Confessions To My Unborn Daughter-c4yRqmkOveg.webm
# [download] 100% of 8.66MiB in 00:0179MiB/s ETA 00:000
# [ffmpeg] Destination: Confessions To My Unborn Daughter-c4yRqmkOveg.mp3
# Deleting original file Confessions To My Unborn Daughter-c4yRqmkOveg.webm (pass -k to keep)
# /opt/anaconda3/envs/metis/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# [youtube] l-dOreXFJyI: Downloading webpage
# [youtube] l-dOreXFJyI: Downloading video info webpage
# [download] Destination: Vartha-l-dOreXFJyI.webm
# [download] 100% of 7.78MiB in 00:0131MiB/s ETA 00:001
# ...
